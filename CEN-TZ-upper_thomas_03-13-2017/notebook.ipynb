# %%
load tap CEN-TZ-upper.txt
# Out:
# Tap: frosty_einstein

# %%
print tap
# Out:
# Coverage:True
# Sibling Disjontness:True
# Regions:mnpw
#
# taxonomy TZ Time_Zone
# (USA Central Eastern Mountain Pacific)
#
# taxonomy CEN Census_Regions
# (USA Midwest Northeast South West)
#
# articulation
# 1. [TZ.Central disjoint CEN.Northeast]
# 2. [TZ.Eastern disjoint CEN.Midwest]
# 3. [TZ.Eastern disjoint CEN.West]
# 4. [TZ.Pacific disjoint CEN.Midwest]
# 5. [TZ.Pacific disjoint CEN.Northeast]
# 6. [TZ.Pacific disjoint CEN.South]
# 7. [TZ.USA equals CEN.USA]
# 8. [TZ.Eastern includes CEN.Northeast]
# 9. [TZ.USA includes CEN.West]
# 10. [TZ.Central is_included_in CEN.USA]
# 11. [TZ.Eastern is_included_in CEN.USA]
# 12. [TZ.Mountain is_included_in CEN.USA]
# 13. [TZ.Pacific is_included_in CEN.USA]
# 14. [TZ.Pacific is_included_in CEN.West]
# 15. [TZ.Central overlaps CEN.Midwest]
# 16. [TZ.Central overlaps CEN.South]
# 17. [TZ.Central overlaps CEN.West]
# 18. [TZ.Eastern overlaps CEN.South]
# 19. [TZ.Mountain overlaps CEN.Midwest]
# 20. [TZ.Mountain overlaps CEN.South]
# ...

# %%
graph tap
# Out:
# Take a look at the produced graph.

# %%
graph worlds
# Out:
# 1 worlds have been produced.

# %%
graph summary
# Out:
# Take a look at the produced graph.

# %%
print config
# Out:
# cli behavior:
#   imageFormat: svg
#   maxWorldsToShow: 5
#   showOutputFileLocation: true
# environment:
#   euler2Executable: euler2
#   htmlViewer: xdg-open {file}
#   imageViewer: xdg-open {file}
# reasoning:
#   defaultIsCoverage: true
#   defaultIsSiblingDisjointness: true
#   defaultRegions: mnpw
#   reasoner: dlv
#   repairMethod: topdown
# sharing:
#   stateGitRepo: ''
#   workspaceGitRepo: http://github.com/EulerProject/experiments

# %%
git push CEN-TZ-upper_thomas_03-13-2017
# Out:
# Pushed successfully
