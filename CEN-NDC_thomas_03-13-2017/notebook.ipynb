# %%
load tap CEN-NDC.txt
# Out:
# Tap: amazing_euclid

# %%
print tap
# Out:
# Coverage:True
# Sibling Disjontness:True
# Regions:mnpw
#
# taxonomy CEN Census_Regions
# (USA Midwest Northeast South West)
# (West AK AZ CA CO HI ID MT NM NV OR UT WA WY)
# (South AL AR DC DE FL GA KY LA MD MS NC OK SC TN TX VA WV)
# (Northeast CT MA ME NH NJ NY PA RI VT)
# (Midwest IA IL IN KS MI MN MO ND NE OH SD WI)
#
# taxonomy NDC National_Diversity_Council
# (USA Midwest Northeast Southeast Southwest West)
# (West CA CO ID MT NV OR UT WA WY)
# (Southwest AZ NM OK TX)
# (Southeast AL AR FL GA KY LA MS NC SC TN VA WV)
# (Northeast CT DE MA MD ME NH NJ NY PA RI VT)
# (Midwest IA IL IN KS MI MN MO ND NE OH SD WI)
#
# articulation
# 1. [CEN.AL equals NDC.AL]
# 2. [CEN.AR equals NDC.AR]
# 3. [CEN.AZ equals NDC.AZ]
# 4. [CEN.CA equals NDC.CA]
# 5. [CEN.CO equals NDC.CO]
# 6. [CEN.CT equals NDC.CT]
# 7. [CEN.DE equals NDC.DE]
# 8. [CEN.FL equals NDC.FL]
# 9. [CEN.GA equals NDC.GA]
# 10. [CEN.IA equals NDC.IA]
# 11. [CEN.ID equals NDC.ID]
# 12. [CEN.IL equals NDC.IL]
# ...

# %%
graph tap
# Out:
# Take a look at the produced graph.

# %%
graph worlds
# Out:
# 1 worlds have been produced.

# %%
graph summary
# Out:
# Take a look at the produced graph.

# %%
print config
# Out:
# cli behavior:
#   imageFormat: svg
#   maxWorldsToShow: 5
#   showOutputFileLocation: true
# environment:
#   euler2Executable: euler2
#   htmlViewer: xdg-open {file}
#   imageViewer: xdg-open {file}
# reasoning:
#   defaultIsCoverage: true
#   defaultIsSiblingDisjointness: true
#   defaultRegions: mnpw
#   reasoner: dlv
#   repairMethod: topdown
# sharing:
#   stateGitRepo: ''
#   workspaceGitRepo: ''

# %%
set config workspaceGitRepo = http://github.com/EulerProject/experiments
# Out:
# Configuration updated: workspaceGitRepo = http://github.com/EulerProject/experiments

# %%
git credentials github.com rodenhausen "my_secret_password"
# Out:
# git credentials set successfully

# %%
git push CEN-NDC_thomas_03-13-2017
# Out:
# Pushed successfully
