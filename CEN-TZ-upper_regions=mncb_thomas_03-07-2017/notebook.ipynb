# %%
load tap CEN-TZ-upper.txt
# Out:
# Tap: vibrant_bassi

# %%
print tap
# Out:
# Coverage:True
# Sibling Disjontness:True
# Regions:mnpw
#
# taxonomy TZ Time_Zone
# (USA Central Eastern Mountain Pacific)
#
# taxonomy CEN Census_Regions
# (USA Midwest Northeast South West)
#
# articulation
# 1. [TZ.Pacific is_included_in CEN.West]
# 2. [TZ.Mountain is_included_in CEN.USA]
# 3. [TZ.USA includes CEN.West]
# 4. [TZ.Eastern is_included_in CEN.USA]
# 5. [TZ.Pacific is_included_in CEN.USA]
# 6. [TZ.USA equals CEN.USA]
# 7. [TZ.Pacific disjoint CEN.Midwest]
# 8. [TZ.Pacific disjoint CEN.South]
# 9. [TZ.Pacific disjoint CEN.Northeast]
# 10. [TZ.Mountain overlaps CEN.West]
# 11. [TZ.Mountain overlaps CEN.Midwest]
# 12. [TZ.Mountain overlaps CEN.South]
# 13. [TZ.Eastern includes CEN.Northeast]
# 14. [TZ.Eastern overlaps CEN.South]
# 15. [TZ.Eastern disjoint CEN.West]
# 16. [TZ.Central is_included_in CEN.USA]
# 17. [TZ.Central overlaps CEN.West]
# 18. [TZ.Central overlaps CEN.Midwest]
# 19. [TZ.Central overlaps CEN.South]
# 20. [TZ.Central disjoint CEN.Northeast]
# ...

# %%
set regions mncb
# Out:
# Tap: sharp_aryabhata

# %%
print tap
# Out:
# Coverage:True
# Sibling Disjontness:True
# Regions:mncb
#
# taxonomy TZ Time_Zone
# (USA Central Eastern Mountain Pacific)
#
# taxonomy CEN Census_Regions
# (USA Midwest Northeast South West)
#
# articulation
# 1. [TZ.Pacific is_included_in CEN.West]
# 2. [TZ.Mountain is_included_in CEN.USA]
# 3. [TZ.USA includes CEN.West]
# 4. [TZ.Eastern is_included_in CEN.USA]
# 5. [TZ.Pacific is_included_in CEN.USA]
# 6. [TZ.USA equals CEN.USA]
# 7. [TZ.Pacific disjoint CEN.Midwest]
# 8. [TZ.Pacific disjoint CEN.South]
# 9. [TZ.Pacific disjoint CEN.Northeast]
# 10. [TZ.Mountain overlaps CEN.West]
# 11. [TZ.Mountain overlaps CEN.Midwest]
# 12. [TZ.Mountain overlaps CEN.South]
# 13. [TZ.Eastern includes CEN.Northeast]
# 14. [TZ.Eastern overlaps CEN.South]
# 15. [TZ.Eastern disjoint CEN.West]
# 16. [TZ.Central is_included_in CEN.USA]
# 17. [TZ.Central overlaps CEN.West]
# 18. [TZ.Central overlaps CEN.Midwest]
# 19. [TZ.Central overlaps CEN.South]
# 20. [TZ.Central disjoint CEN.Northeast]
# ...

# %%
graph tap
# Out:
# Take a look at the graph

# %%
graph worlds
# Out:
# There are 1 possible worlds. I show them all to you.

# %%
graph summary
# Out:
# Take a look at the graph

# %%
print config
# Out:
# defaultIsSiblingDisjointness = True
# euler2Executable = euler2
# imageViewer = xdg-open {file}
# defaultRegions = mnpw
# showOutputFileLocation = True
# htmlViewer = xdg-open {file}
# defaultIsCoverage = True
# reasoner = dlv
# imageFormat = svg
# cacheGitRepo =
# workspaceGitRepo = http://github.com/EulerProject/experiments
# maxPossibleWorldsToShow = 5
# repairMethod = topdown

# %%
git push CEN-TZ-upper_regions=mncb_thomas_03-07-2017
# Out:
# Pushed successfully
